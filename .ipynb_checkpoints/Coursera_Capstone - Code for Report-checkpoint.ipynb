# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv', sep=',', delimiter=None, header='infer')
df.head(3)
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# ...

# %%
pd.set_option('display.max_columns', None)
df1=df 
df1.tail()
# Out:
#         SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 194668             2 -122.290826  47.565408    219543  309534     310814
# 194669             1 -122.344526  47.690924    219544  309085     310365
# 194670             2 -122.306689  47.683047    219545  311280     312640
# 194671             2 -122.355317  47.678734    219546  309514     310794
# 194672             1 -122.289360  47.611017    219547  308220     309500
#
#        REPORTNO   STATUS      ADDRTYPE   INTKEY  \
# 194668  E871089  Matched         Block      NaN
# 194669  E876731  Matched         Block      NaN
# 194670  3809984  Matched  Intersection  24760.0
# 194671  3810083  Matched  Intersection  24349.0
# 194672  E868008  Matched         Block      NaN
#
#                                                LOCATION EXCEPTRSNCODE  \
# 194668  34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# 194669     AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# ...

# %%
df.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %%
df[df['REPORTNO']=="1776526"] #string
# Out:
#        SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 3647              2 -122.329047  47.595387      4264   12923      12923
# 11799             2 -122.329047  47.595387     14900   28573      28573
#
#       REPORTNO   STATUS ADDRTYPE  INTKEY  \
# 3647   1776526  Matched    Block     NaN
# 11799  1776526  Matched    Block     NaN
#
#                                                 LOCATION EXCEPTRSNCODE  \
# 3647   4TH AVE S BETWEEN SEATTLE BLVD S AND I90 WB 4T...           NaN
# 11799  4TH AVE S BETWEEN SEATTLE BLVD S AND I90 WB 4T...           NaN
#
#       EXCEPTRSNDESC  SEVERITYCODE.1      SEVERITYDESC COLLISIONTYPE  \
# 3647            NaN               2  Injury Collision        Cycles
# 11799           NaN               2  Injury Collision        Cycles
#
#        PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT                 INCDATE  \
# 3647             2         0            1         1  2004/04/21 00:00:00+00
# ...

# %%
df1.drop(['X','Y','SEVERITYCODE.1','OBJECTID','INCKEY','COLDETKEY','EXCEPTRSNCODE','EXCEPTRSNDESC'], axis=1, index=None, columns=None, level=None, inplace=True, errors='raise')

# %%
df1.drop(['SDOTCOLNUM'], axis=1, index=None, columns=None, level=None, inplace=True, errors='raise')

# %%
df1.columns
# Out:
# Index(['SEVERITYCODE', 'REPORTNO', 'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION',
#        'SEVERITYDESC', 'COLLISIONTYPE', 'PERSONCOUNT', 'PEDCOUNT',
#        'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE',
#        'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL',
#        'WEATHER', 'ROADCOND', 'LIGHTCOND', 'PEDROWNOTGRNT', 'SPEEDING',
#        'ST_COLCODE', 'ST_COLDESC', 'SEGLANEKEY', 'CROSSWALKKEY',
#        'HITPARKEDCAR'],
#       dtype='object')

# %% [markdown]
# this notebook will be mainly used for the capstone project.

# %% [markdown]
# ******************
# <p> Remark:
# <p> REPORTNO have duplication
#
# <p> STATUS  has 4800 unmatched, 188k Matched
#
# <P> unmatched matched
#
# ******************
#
# Missing:
# SHAPE
#
# SERIOUSINJURIES
#
# FATALITIES
#
# INCDATE
#
# Meta data:
# https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Metadata.pdf

# %%
import numpy as np
import pandas as pd

print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv', sep=',', delimiter=None, header='infer')

# %%
pd.set_option('display.max_columns', None)

# %%
df.tail(1)
# Out:
#         SEVERITYCODE          X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 194672             1 -122.28936  47.611017    219547  308220     309500
#
#        REPORTNO   STATUS ADDRTYPE  INTKEY  \
# 194672  E868008  Matched    Block     NaN
#
#                                             LOCATION EXCEPTRSNCODE  \
# 194672  34TH AVE BETWEEN E MARION ST AND E SPRING ST
#
#        EXCEPTRSNDESC  SEVERITYCODE.1                    SEVERITYDESC  \
# 194672           NaN               1  Property Damage Only Collision
#
#        COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 194672    Rear Ended            2         0            0         2
#
#                        INCDATE                INCDTTM  \
# 194672  2018/11/30 00:00:00+00  11/30/2018 3:45:00 PM
#
#                                    JUNCTIONTYPE  SDOT_COLCODE  \
# 194672  Mid-Block (not related to intersection)            14
#
#                                         SDOT_COLDESC INATTENTIONIND UNDERINFL  \
# ...

# %%
df1=df

# %%
df1['EXCEPTRSNCODE'].sort_values(ascending=False)

# %%
df.EXCEPTRSNCODE.unique()
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)[source]
# Out:
# array([' ', nan, 'NEI'], dtype=object)

# %%
df.EXCEPTRSNDESC.unique()
# Out:
# array([nan,
#        'Not Enough Information, or Insufficient Location Information'],
#       dtype=object)

# %%
df["SEGLANEKEY"].sort_values(ascending=False)
df["CROSSWALKKEY"].sort_values(ascending=False)
# Out:
# 179239    5239700
# 190662     703480
# 155646     701306
# 154757     701280
# 159132     701110
# 162519     700526
# 171420     700388
# 170462     699889
# 168430     699879
# 175133     699876
# 169599     699738
# 164943     699736
# 167476     699723
# 151195     699720
# 170966     699687
# 171222     699680
# 162068     696052
# 149912     678782
# 152912     668165
# 152877     664953
# 161703     664366
# 164254     664365
# 194655     650595
# 178394     642420
# 157766     642419
# 167977     642408
# 181256     642048
# 180789     638921
# 157045     638921
# 187665     638921
#            ...
# 128780          0
# 128779          0
# 128778          0
# 128777          0
# 128776          0
# 128775          0
# 128794          0
# 128796          0
# 128817          0
# 128797          0
# 128816          0
# 128815          0
# 128814          0
# 128813          0
# 128812          0
# 128811          0
# 128810          0
# 128809          0
# 128808          0
# ...

# %%
df[df["HITPARKEDCAR"]=="Y"].count()
# Out:
# SEVERITYCODE      7216
# X                 7005
# Y                 7005
# OBJECTID          7216
# INCKEY            7216
# COLDETKEY         7216
# REPORTNO          7216
# STATUS            7216
# ADDRTYPE          7017
# INTKEY             176
# LOCATION          7015
# EXCEPTRSNCODE     7216
# EXCEPTRSNDESC     1264
# SEVERITYCODE.1    7216
# SEVERITYDESC      7216
# COLLISIONTYPE     6916
# PERSONCOUNT       7216
# PEDCOUNT          7216
# PEDCYLCOUNT       7216
# VEHCOUNT          7216
# INCDATE           7216
# INCDTTM           7216
# JUNCTIONTYPE      6083
# SDOT_COLCODE      7216
# SDOT_COLDESC      7216
# INATTENTIONIND    1263
# UNDERINFL         6918
# WEATHER           6880
# ROADCOND          6885
# LIGHTCOND         6868
# PEDROWNOTGRNT        0
# SDOTCOLNUM           1
# SPEEDING           123
# ST_COLCODE        7216
# ST_COLDESC        6916
# SEGLANEKEY        7216
# CROSSWALKKEY      7216
# HITPARKEDCAR      7216
# dtype: int64

# %% [markdown]
# <p><h1>Check aginst the Meta Data</h1>
# <p>
# <p><h2>More:</h2>
# <p>REPORTNO           object
# <p>STATUS             object
# <p>SEVERITYCODE        int64
# <p>X                 float64
# <p>Y                 float64
# <p>
#
#
# <p><h2>Missing:</h2>
# <p>SHAPE
# <p><p>SERIOUSINJURIES
# <p>FATALITIES
# <p>INCDATE
# <p>
# <p><h2>Meta data:</h2>
# <p>https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Metadata.pdf

# %%
df.dtypes
# Out:
# SEVERITYCODE        int64
# X                 float64
# Y                 float64
# OBJECTID            int64
# INCKEY              int64
# COLDETKEY           int64
# REPORTNO           object
# STATUS             object
# ADDRTYPE           object
# INTKEY            float64
# LOCATION           object
# EXCEPTRSNCODE      object
# EXCEPTRSNDESC      object
# SEVERITYCODE.1      int64
# SEVERITYDESC       object
# COLLISIONTYPE      object
# PERSONCOUNT         int64
# PEDCOUNT            int64
# PEDCYLCOUNT         int64
# VEHCOUNT            int64
# INCDATE            object
# INCDTTM            object
# JUNCTIONTYPE       object
# SDOT_COLCODE        int64
# SDOT_COLDESC       object
# INATTENTIONIND     object
# UNDERINFL          object
# WEATHER            object
# ROADCOND           object
# LIGHTCOND          object
# PEDROWNOTGRNT      object
# SDOTCOLNUM        float64
# SPEEDING           object
# ST_COLCODE         object
# ST_COLDESC         object
# ...

# %%
df[df.duplicated(subset=['REPORTNO'])]
# Out:
#        SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 2829              1 -122.318958  47.695842      3272   16918      16918
# 7231              2 -122.355302  47.682178      8981   22777      22777
# 11799             2 -122.329047  47.595387     14900   28573      28573
#
#       REPORTNO   STATUS ADDRTYPE  INTKEY  \
# 2829   1780512  Matched    Block     NaN
# 7231   1782439  Matched    Block     NaN
# 11799  1776526  Matched    Block     NaN
#
#                                                 LOCATION EXCEPTRSNCODE  \
# 2829   NE 92ND ST BETWEEN 8TH AVE NE AND ROOSEVELT WA...           NaN
# 7231     GREENWOOD AVE N BETWEEN N 73RD ST AND N 74TH ST           NaN
# 11799  4TH AVE S BETWEEN SEATTLE BLVD S AND I90 WB 4T...           NaN
#
#       EXCEPTRSNDESC  SEVERITYCODE.1                    SEVERITYDESC  \
# 2829            NaN               1  Property Damage Only Collision
# 7231            NaN               2                Injury Collision
# ...

# %%
df[df['REPORTNO']=="1776526"]
# Out:
#        SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY  \
# 3647              2 -122.329047  47.595387      4264   12923      12923
# 11799             2 -122.329047  47.595387     14900   28573      28573
#
#       REPORTNO   STATUS ADDRTYPE  INTKEY  \
# 3647   1776526  Matched    Block     NaN
# 11799  1776526  Matched    Block     NaN
#
#                                                 LOCATION EXCEPTRSNCODE  \
# 3647   4TH AVE S BETWEEN SEATTLE BLVD S AND I90 WB 4T...           NaN
# 11799  4TH AVE S BETWEEN SEATTLE BLVD S AND I90 WB 4T...           NaN
#
#       EXCEPTRSNDESC  SEVERITYCODE.1      SEVERITYDESC COLLISIONTYPE  \
# 3647            NaN               2  Injury Collision        Cycles
# 11799           NaN               2  Injury Collision        Cycles
#
#        PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT                 INCDATE  \
# 3647             2         0            1         1  2004/04/21 00:00:00+00
# ...

# %%
df2=df

# %%
df2.drop(['X','Y','SEVERITYCODE.1','OBJECTID','INCKEY','COLDETKEY','EXCEPTRSNCODE','EXCEPTRSNDESC'], axis=1, index=None, columns=None, level=None, inplace=True, errors='raise')

# %%
df2.head()
# Out:
#    SEVERITYCODE REPORTNO   STATUS      ADDRTYPE   INTKEY  \
# 0             2  3502005  Matched  Intersection  37475.0
# 1             1  2607959  Matched         Block      NaN
# 2             1  1482393  Matched         Block      NaN
# 3             1  3503937  Matched         Block      NaN
# 4             2  1807429  Matched  Intersection  34387.0
#
#                                       LOCATION  \
# 0                   5TH AVE NE AND NE 103RD ST
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST
# 4              SWIFT AVE S AND SWIFT AV OFF RP
#
#                      SEVERITYDESC COLLISIONTYPE  PERSONCOUNT  PEDCOUNT  \
# 0                Injury Collision        Angles            2         0
# 1  Property Damage Only Collision     Sideswipe            2         0
# 2  Property Damage Only Collision    Parked Car            4         0
# ...

# %%
For the FIRST week, you will required to submit the following:

A description of the problem and a discussion of the background. (15 marks)

# %%
A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# For the FIRST week, you will required to submit the following:
# <br>
# <p>A description of the problem and a discussion of the background. (15 marks)
# <p>A description of the data and how it will be used to solve the problem. (15 marks)
# <br>

# %% [markdown]
# For the SECOND week, the final deliverables of the project will be:
# <br>
# <p>1. A link to your Notebook on your Github repository, showing your code. (15 marks)
# <br>
# <p>2. A full report consisting of all of the following components (15 marks):
# - Introduction where you discuss the business problem and who would be interested in this project.
# - Data where you describe the data that will be used to solve the problem and the source of the data.
# - Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# - Results section where you discuss the results.
# - Discussion section where you discuss any observations you noted and any recommendations you can make based on the - results.
# - Conclusion section where you conclude the report.
# <br>

# %% [markdown]
# <p>3. Your choice of a presentation or blogpost. (10 marks)
# <br>
# Here are examples of previous outstanding submissions that should give you an idea of what your report would look like, what your notebook would look like in terms of clean, clear, and well-commented code, and what your presentation would look like or your blogpost would look like:
# <br>
# <P>Report: https://cocl.us/coursera_capstone_report
# <P>Notebook: https://cocl.us/coursera_capstone_notebook
# <P>Presentation: https://cocl.us/coursera_capstone_presentation
# <P>Blogpost: https://cocl.us/coursera_capstone_blogpost
#
# <br>
